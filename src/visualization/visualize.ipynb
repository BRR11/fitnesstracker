# %%
for label in df["label"].unique():
    subset = df[df["label"] == label]
    fig,ax = plt.subplots()
    plt.plot(subset[:100]["acc_y"].reset_index(drop=True),label = label)
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for label in df["label"].unique():
#       2     subset = df[df["label"] == label]
#       3     fig,ax = plt.subplots()
#
# NameError: name 'df' is not defined

# %%
category_df = df.query("label == 'squat'").query("participant == 'A'").reset_index()

fig,ax = plt.subplots()
category_df.head()

category_df.groupby(["category"],group_keys=True)["acc_y"].plot()

ax.set_ylabel("acc_y")
ax.set_xlabel("samples")
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
participants_df = df.query("label == 'bench'").sort_values("participant").reset_index()
fig,ax = plt.subplots()

participants_df.groupby(["participant"],group_keys=True)["acc_y"].plot()

ax.set_ylabel("acc_y")
ax.set_xlabel("samples")
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
import matplotlib.pyplot as plt

participants_df = df.query("label == 'bench'").sort_values("participant").reset_index()

# Plot only the first 50 values for each participant
participants_df_grouped = participants_df.groupby("participant").head(50)

fig, ax = plt.subplots()
participants_df_grouped.groupby("participant")["acc_y"].plot(legend=True)

ax.set_ylabel("acc_y")
ax.set_xlabel("samples")
plt.legend(participants_df_grouped["participant"].unique())  # Add legend with participant IDs
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 participants_df = df.query("label == 'bench'").sort_values("participant").reset_index()
#       5 # Plot only the first 50 values for each participant
#       6 participants_df_grouped = participants_df.groupby("participant").head(50)
#
# NameError: name 'df' is not defined
